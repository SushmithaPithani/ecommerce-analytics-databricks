# %%
# %sh
pwd
ls -R

# %%
# %sh
cd ..
ls -R

# %%
customers_df = spark.read.csv(
    "/Workspace/Repos/sushmithalakshmi1010@gmail.com/ecommerce-analytics-databricks/data/olist_customers_dataset.csv",
    header=True,
    inferSchema=True
)

display(customers_df)

# %%
products_df = spark.read.csv("/Workspace/Repos/sushmithalakshmi1010@gmail.com/ecommerce-analytics-databricks/data/olist_products_dataset.csv", header = True, inferSchema = True)
display(products_df)

# %%
orders_df = spark.read.csv("/Workspace/Repos/sushmithalakshmi1010@gmail.com/ecommerce-analytics-databricks/data/olist_orders_dataset.csv",header=True,inferSchema =True)
display(orders_df)

# %%
# %sh
ls /Workspace/Repos/sushmithalakshmi1010@gmail.com/ecommerce-analytics-databricks/data

# %%
order_items_df = spark.read.csv("/Workspace/Repos/sushmithalakshmi1010@gmail.com/ecommerce-analytics-databricks/data/olist_order_items_dataset - Copy.csv",header=True,inferSchema=True)
display(order_items_df)

# %%
order_payments_df = spark.read.csv("/Workspace/Repos/sushmithalakshmi1010@gmail.com/ecommerce-analytics-databricks/data/olist_order_payments_dataset.csv",header=True,inferSchema=True)
display(order_payments_df)

# %%
order_reviews_df = spark.read.csv("/Workspace/Repos/sushmithalakshmi1010@gmail.com/ecommerce-analytics-databricks/data/olist_order_reviews_dataset.csv",header=True,inferSchema=True)
display(order_reviews_df)

# %%
order_sellers_df = spark.read.csv("/Workspace/Repos/sushmithalakshmi1010@gmail.com/ecommerce-analytics-databricks/data/olist_sellers_dataset.csv",header=True,inferSchema=True)
display(order_sellers_df)

# %%
category_df = spark.read.csv("/Workspace/Repos/sushmithalakshmi1010@gmail.com/ecommerce-analytics-databricks/data/product_category_name_translation.csv",header = True, inferSchema =True)
display(category_df)

# %%
customers_df.count()
orders_df.count()
products_df.count()
order_items_df.count()
order_payments_df.count()
order_reviews_df.count()
order_sellers_df.count()
category_df.count()

# %%
customers_df.printSchema()
orders_df.printSchema()

# %%
customers_df.write.format("delta").mode("overwrite").saveAsTable("bronze_customers")

# %%
spark.sql("DROP TABLE IF EXISTS bronze_order_items")

# %%
orders_df.write.format("delta").mode("overwrite").saveAsTable("bronze_orders")

products_df.write.format("delta").mode("overwrite").saveAsTable("bronze_products")

order_items_df.write.format("delta").mode("overwrite").saveAsTable("bronze_order_items")

# %%
order_reviews_df.write.format("delta").mode("overwrite").saveAsTable("bronze_reviews")

order_sellers_df.write.format("delta").mode("overwrite").saveAsTable("bronze_sellers")

category_df.write.format("delta").mode("overwrite").saveAsTable("bronze_category_translation")

# %%
spark.sql("SHOW TABLES").show(truncate=False)

# %%
spark.catalog.listTables()
